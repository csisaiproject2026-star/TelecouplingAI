# %%
  - matplotlib
  - geopandas
  - rasterio
  - gdal
  - shapely
  - scikit-learn
  - fastapi
  - uvicorn
  - pydantic
  - requests
  - python-dotenv
  - pip


      - scipy
      - frozenlist
# Out:
# 开始创建项目: telecoupling-project
# ✅ 已创建目录: telecoupling-project/backend/app
# ✅ 已创建目录: telecoupling-project/backend/agents
# ✅ 已创建目录: telecoupling-project/backend/tools
# ✅ 已创建目录: telecoupling-project/backend/database
# ✅ 已创建目录: telecoupling-project/data/db_files
# ✅ 已创建目录: telecoupling-project/data/logs
# ✅ 已创建目录: telecoupling-project/nginx/certs
# 📝 已生成文件: telecoupling-project/backend/requirements.txt
# 📝 已生成文件: telecoupling-project/backend/config.py
# 📝 已生成文件: telecoupling-project/backend/main.py
# 📝 已生成文件: telecoupling-project/docker-compose.yml
# 📝 已生成文件: telecoupling-project/.env
# \n✨ 所有文件已就绪！现在你可以进入目录开始开发了。
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
